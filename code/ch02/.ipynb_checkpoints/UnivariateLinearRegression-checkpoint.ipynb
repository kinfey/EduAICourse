# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'http://www.tianqihoubao.com/lishi/shanghai/month/202009.html'
resp = requests.get(url)
html = resp.content.decode('gbk')
soup = BeautifulSoup(html,'html.parser')
tr_list = soup.find_all('tr')
_dates = 1
dates,contains,temp = [],[],[]
for data in tr_list[1:]:  
    sub_data = data.text.split()
    dates.append(str(_dates))
    contains.append(','.join(sub_data[1:3]))
    temp.append(','.join(sub_data[3:6]))
    _dates += 1
_data = pd.DataFrame()
_data['Date'] = dates
_data['Weather'] = contains
_data['Temperature'] = temp

# %%
data = pd.concat([_data]).reset_index(drop = True)

# %%
data.to_csv('./shanghai_sep_weather.csv',encoding='utf-8')

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('./shanghai_sep_weather.csv')

# %%
data['HighTemperature'] = data['Temperature'].str.split('/',expand=True)[0]
data['LowTemperature'] = data['Temperature'].str.split('/',expand=True)[1]
data['HighTemperature'] = data['HighTemperature'].map(lambda x:x.replace('℃,',''))
print(data['HighTemperature'])
data['LowTemperature'] = data['LowTemperature'].map(lambda x:x.replace(',',''))
data['LowTemperature'] = data['LowTemperature'].map(lambda x:x.replace('℃',''))
print(data['LowTemperature'])
# Out:
# 0     31
# 1     30
# 2     30
# 3     32
# 4     32
# 5     31
# 6     33
# 7     35
# 8     33
# 9     30
# 10    27
# 11    28
# 12    28
# 13    27
# 14    25
# 15    27
# 16    24
# 17    19
# 18    23
# 19    28
# 20    26
# 21    24
# 22    21
# 23    26
# 24    25
# 25    26
# 26    25
# 27    25
# 28    26
# 29    27
# Name: HighTemperature, dtype: object
# 0     26
# 1     24
# 2     23
# 3     24
# 4     23
# 5     24
# 6     25
# 7     24
# 8     24
# 9     24
# 10    22
# 11    22
# 12    22
# 13    23
# 14    22
# 15    22
# 16    19
# 17    17
# 18    19
# 19    21
# 20    19
# 21    20
# 22    18
# 23    19
# 24    20
# 25    20
# 26    20
# 27    20
# 28    19
# 29    19
# Name: LowTemperature, dtype: object

# %%
dates = data['Date']
highs = data['HighTemperature']
lows = data['LowTemperature']
print(highs)
# Out:
# 0     31
# 1     30
# 2     30
# 3     32
# 4     32
# 5     31
# 6     33
# 7     35
# 8     33
# 9     30
# 10    27
# 11    28
# 12    28
# 13    27
# 14    25
# 15    27
# 16    24
# 17    19
# 18    23
# 19    28
# 20    26
# 21    24
# 22    21
# 23    26
# 24    25
# 25    26
# 26    25
# 27    25
# 28    26
# 29    27
# Name: HighTemperature, dtype: object

# %%
fig = plt.figure(dpi=128,figsize=(10,6))
#L1,=plt.plot(dates,lows,label='LowTemperature')
L2,=plt.plot(dates,highs,label='HighTemperature')
#plt.legend(handles=[L1,L2],labels=['HighTemperature','LowTemperature'], loc='best')
plt.title('Shanghai weather Sep 2020',fontsize=25)  # 字体大小设置为25
plt.xlabel('Date',fontsize=10)   # x轴显示“日期”，字体大小设置为10
fig.autofmt_xdate() # 绘制斜的日期标签，避免重叠
plt.ylabel('Temperature',fontsize=10)  # y轴显示“气温”，字体大小设置为10
plt.tick_params(axis='both',which='major',labelsize=10)
plt.xticks(dates[::1]) 

fig = plt.figure(dpi=128,figsize=(10,6))
# color可以百度颜色代码
# plt.plot(dates,y_1,label="自己",color="#F08080")
# plt.plot(dates,y_2,label="同桌",color="#DB7093",linestyle="--")

# L1,=plt.plot(dates,lows,label='LowTemperature')
# L2,=plt.plot(dates,highs,label='HighTemperature')
 
# #设置x轴刻度
# # _xtick_labels = ["{}岁".format(i) for i in x]
# plt.xlabel('Date',fontsize=10)
# plt.xticks(dates[::1])
# plt.yticks(range(0,40))
 
# #绘制网格
# plt.grid(alpha=0.4,linestyle=':')

# %%
plt.show()
