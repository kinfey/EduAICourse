# %%
from sklearn.datasets import load_boston
from numpy import *
import matplotlib.pyplot as plt 
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn import preprocessing
boston = load_boston()

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of black people by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
print("Shape of Dataset : ", boston.data.shape)
print("Feature names : ", boston.feature_names)
print("Target Values : ", boston.target[:20])
# Out:
# Shape of Dataset :  (506, 13)
# Feature names :  ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# Target Values :  [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2]

# %%
import pandas as pd
X = pd.DataFrame(boston.data, columns = boston.feature_names)
Y = boston.target   

print(X.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.33, random_state = 5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
print(X_train.head(2))                                              # Standardizing Data 
print(X_train.head(2))
# Out:
# (339, 13)
# (167, 13)
# (339,)
# (167,)
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 435  11.1604  0.0  18.10   0.0  0.740  6.629  94.6  2.1247  24.0  666.0
# 88    0.0566  0.0   3.41   0.0  0.489  7.007  86.3  3.4217   2.0  270.0
#
#      PTRATIO       B  LSTAT
# 435     20.2  109.85  23.27
# 88      17.8  396.90   5.50
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 435  11.1604  0.0  18.10   0.0  0.740  6.629  94.6  2.1247  24.0  666.0
# 88    0.0566  0.0   3.41   0.0  0.489  7.007  86.3  3.4217   2.0  270.0
#
#      PTRATIO       B  LSTAT
# 435     20.2  109.85  23.27
# 88      17.8  396.90   5.50

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

lm = LinearRegression()
lm.fit(X_train, Y_train)


y_pred_from_sklearn = lm.predict(X_test)

plt.scatter(Y_test, y_pred_from_sklearn)
plt.xlabel("Prices: $Y_i$")
plt.ylabel("Predicted prices: $\hat{Y}_i$")
plt.title("Prices vs Predicted prices: $Y_i$ vs $\hat{Y}_i$")
plt.show()

# %%
sklearn_pred_df = pd.DataFrame(
    {
        'Actual Value' : Y_test, 
     'Predicted Values' : y_pred_from_sklearn
    }
)
sklearn_pred_df.head(10)
# Out:
#    Actual Value  Predicted Values
# 0          37.6         37.467236
# 1          27.9         31.391547
# 2          22.6         27.120196
# 3          13.8          6.468433
# 4          35.2         33.629667
# 5          10.4          5.670680
# 6          23.9         27.039467
# 7          29.0         29.927047
# 8          22.8         26.356613
# 9          23.2         22.452460

# %%
X_train_standardized = (X_train - X_train .mean()) / X_train.std()
X_test_standardized  = (X_test - X_train.mean()) /  X_train.std()

# %%
def error_function(y_actual,y_predicted):
    error = 0
    for i in range(0,len(y_actual)):
        error =  error + pow((y_actual[i] - y_predicted[i]),2)
        return error/(2*len(y_actual))

def y_predicted(w,x):
    y_pred = np.zeros(len(x))
    for i in range(0,len(x)):
        for j in range(0,len(w)):
            y_pred[i] = y_pred[i]+(w[j]*x[i][j] + w[-1])
    return y_pred

def gradient_descent(y_actual,y_pred,x):
    grad = np.zeros(x.shape[1])
    for i in range(x.shape[1]):
        for j in range(0,len(y_actual)):
            grad[i] = - (y_actual[j] - y_pred[j])*x[j][i] + grad[i]
    return grad/len(y_actual)

def weights(x_train,y_train,num_iterations,learning_rate):
    no_of_rows = x_train.shape[0]
    no_of_columns = x_train.shape[1]
    new_x_train = np.ones((no_of_rows,no_of_columns+1))
    new_x_train[:,0:no_of_columns] = x_train
    w = np.zeros(no_of_columns)
    w =np.append(w,1)
    for i in range(0,num_iterations):
        y_pred = y_predicted(w,new_x_train)
        error = error_function(y_train,y_pred)
        print("mean square error: ",error,"after",i,"th iteration")
        MSE_points.append(error)
        grad = gradient_descent(y_train,y_pred,new_x_train)
        w = w - learning_rate*grad
        learning_rate = learning_rate/1.05                             
    return w

def regression_test(x_test,w):
    row = x_test.shape[0]
    column = x_test.shape[1]
    new_x_test = np.ones((row,column+1))
    new_x_test[:,0:column] = x_test
    y_pred = y_predicted(w,new_x_test)
    return(y_pred)

# %%
MSE_points = []
num_iterations = 300
learning_rate = 0.1
w = weights(X_train_standardized,Y_train,num_iterations,learning_rate)
Y_pred = regression_test(X_test_standardized,w)
error_function(Y_test,Y_pred)
# Out:
# mean square error:  0.003775811209439526 after 0 th iteration
# mean square error:  0.08267258279493286 after 1 th iteration
# mean square error:  4.519339260637004e-05 after 2 th iteration
# mean square error:  0.004138636437771344 after 3 th iteration
# mean square error:  0.0006857779989616983 after 4 th iteration
# mean square error:  0.0010223468075220624 after 5 th iteration
# mean square error:  0.0009240258755377499 after 6 th iteration
# mean square error:  0.0010168313257835264 after 7 th iteration
# mean square error:  0.0011085528181208248 after 8 th iteration
# mean square error:  0.0012050536323118589 after 9 th iteration
# mean square error:  0.0012959134389107741 after 10 th iteration
# mean square error:  0.0013778817988608927 after 11 th iteration
# mean square error:  0.0014498480746630985 after 12 th iteration
# mean square error:  0.0015118682814598315 after 13 th iteration
# mean square error:  0.0015645678061702178 after 14 th iteration
# mean square error:  0.0016088206593499433 after 15 th iteration
# mean square error:  0.0016455768000353567 after 16 th iteration
# mean square error:  0.0016757710749658497 after 17 th iteration
# mean square error:  0.0017002776860356715 after 18 th iteration
# mean square error:  0.001719890114040865 after 19 th iteration
# mean square error:  0.0017353151470741385 after 20 th iteration
# mean square error:  0.0017471745224180832 after 21 th iteration
# mean square error:  0.001756010450782663 after 22 th iteration
# mean square error:  0.0017622928826295347 after 23 th iteration
# mean square error:  0.001766427303823315 after 24 th iteration
# mean square error:  0.001768762392503537 after 25 th iteration
# mean square error:  0.0017695971895834413 after 26 th iteration
# mean square error:  0.0017691876230333636 after 27 th iteration
# mean square error:  0.0017677523345560222 after 28 th iteration
# mean square error:  0.001765477818123569 after 29 th iteration
# mean square error:  0.0017625229121571774 after 30 th iteration
# mean square error:  0.0017590227024185166 after 31 th iteration
# mean square error:  0.0017550918979726778 after 32 th iteration
# mean square error:  0.0017508277421669476 after 33 th iteration
# mean square error:  0.001746312517064334 after 34 th iteration
# mean square error:  0.0017416156947590565 after 35 th iteration
# mean square error:  0.0017367957834266783 after 36 th iteration
# mean square error:  0.0017319019103712394 after 37 th iteration
# mean square error:  0.001726975179027643 after 38 th iteration
# mean square error:  0.0017220498320096743 after 39 th iteration
# mean square error:  0.0017171542479263104 after 40 th iteration
# mean square error:  0.0017123117958249378 after 41 th iteration
# mean square error:  0.0017075415677409809 after 42 th iteration
# mean square error:  0.00170285900689893 after 43 th iteration
# mean square error:  0.0016982764465764619 after 44 th iteration
# mean square error:  0.0016938035724654496 after 45 th iteration
# mean square error:  0.001689447819495901 after 46 th iteration
# mean square error:  0.0016852147124923023 after 47 th iteration
# mean square error:  0.0016811081586674591 after 48 th iteration
# mean square error:  0.0016771306987944923 after 49 th iteration
# mean square error:  0.0016732837229060194 after 50 th iteration
# mean square error:  0.0016695676555225048 after 51 th iteration
# mean square error:  0.0016659821146912284 after 52 th iteration
# mean square error:  0.0016625260485020755 after 53 th iteration
# mean square error:  0.0016591978522218784 after 54 th iteration
# mean square error:  0.0016559954687421741 after 55 th iteration
# mean square error:  0.0016529164746523681 after 56 th iteration
# mean square error:  0.0016499581539251421 after 57 th iteration
# mean square error:  0.0016471175609210206 after 58 th iteration
# mean square error:  0.0016443915741811495 after 59 th iteration
# mean square error:  0.0016417769422726943 after 60 th iteration
# mean square error:  0.0016392703227763458 after 61 th iteration
# mean square error:  0.001636868315355506 after 62 th iteration
# mean square error:  0.0016345674897173586 after 63 th iteration
# mean square error:  0.001632364409166062 after 64 th iteration
# mean square error:  0.0016302556503525808 after 65 th iteration
# mean square error:  0.0016282378197439492 after 66 th iteration
# mean square error:  0.0016263075672642434 after 67 th iteration
# mean square error:  0.001624461597498848 after 68 th iteration
# mean square error:  0.0016226966788005766 after 69 th iteration
# mean square error:  0.0016210096505917555 after 70 th iteration
# mean square error:  0.0016193974291163736 after 71 th iteration
# mean square error:  0.0016178570118631798 after 72 th iteration
# mean square error:  0.0016163854808506429 after 73 th iteration
# mean square error:  0.001614980004940019 after 74 th iteration
# mean square error:  0.001613637841320182 after 75 th iteration
# mean square error:  0.0016123563362889157 after 76 th iteration
# mean square error:  0.0016111329254389984 after 77 th iteration
# mean square error:  0.0016099651333426695 after 78 th iteration
# mean square error:  0.0016088505728159579 after 79 th iteration
# mean square error:  0.0016077869438329753 after 80 th iteration
# mean square error:  0.0016067720321513562 after 81 th iteration
# mean square error:  0.001605803707701272 after 82 th iteration
# mean square error:  0.0016048799227838144 after 83 th iteration
# mean square error:  0.0016039987101177228 after 84 th iteration
# mean square error:  0.0016031581807684856 after 85 th iteration
# mean square error:  0.0016023565219887722 after 86 th iteration
# mean square error:  0.001601591994995427 after 87 th iteration
# mean square error:  0.0016008629327039846 after 88 th iteration
# mean square error:  0.001600167737439277 after 89 th iteration
# mean square error:  0.0015995048786376495 after 90 th iteration
# mean square error:  0.0015988728905535921 after 91 th iteration
# mean square error:  0.0015982703699823637 after 92 th iteration
# mean square error:  0.0015976959740074085 after 93 th iteration
# mean square error:  0.0015971484177806665 after 94 th iteration
# mean square error:  0.0015966264723417927 after 95 th iteration
# mean square error:  0.001596128962481858 after 96 th iteration
# mean square error:  0.0015956547646552048 after 97 th iteration
# mean square error:  0.0015952028049432496 after 98 th iteration
# mean square error:  0.001594772057072397 after 99 th iteration
# mean square error:  0.0015943615404879763 after 100 th iteration
# mean square error:  0.001593970318485652 after 101 th iteration
# mean square error:  0.001593597496400925 after 102 th iteration
# mean square error:  0.0015932422198572346 after 103 th iteration
# mean square error:  0.0015929036730726461 after 104 th iteration
# mean square error:  0.001592581077224856 after 105 th iteration
# mean square error:  0.0015922736888740443 after 106 th iteration
# mean square error:  0.0015919807984427937 after 107 th iteration
# mean square error:  0.0015917017287522405 after 108 th iteration
# mean square error:  0.0015914358336132663 after 109 th iteration
# mean square error:  0.001591182496471806 after 110 th iteration
# mean square error:  0.0015909411291067058 after 111 th iteration
# mean square error:  0.0015907111703790861 after 112 th iteration
# mean square error:  0.0015904920850316059 after 113 th iteration
# mean square error:  0.0015902833625363255 after 114 th iteration
# mean square error:  0.0015900845159896103 after 115 th iteration
# mean square error:  0.0015898950810526989 after 116 th iteration
# mean square error:  0.0015897146149363673 after 117 th iteration
# mean square error:  0.0015895426954282354 after 118 th iteration
# mean square error:  0.0015893789199613317 after 119 th iteration
# mean square error:  0.0015892229047221242 after 120 th iteration
# mean square error:  0.0015890742837972474 after 121 th iteration
# mean square error:  0.001588932708356649 after 122 th iteration
# mean square error:  0.0015887978458724915 after 123 th iteration
# mean square error:  0.001588669379372066 after 124 th iteration
# mean square error:  0.0015885470067235074 after 125 th iteration
# mean square error:  0.0015884304399530103 after 126 th iteration
# mean square error:  0.0015883194045922726 after 127 th iteration
# mean square error:  0.0015882136390549194 after 128 th iteration
# mean square error:  0.0015881128940408928 after 129 th iteration
# mean square error:  0.001588016931967347 after 130 th iteration
# mean square error:  0.0015879255264252233 after 131 th iteration
# mean square error:  0.0015878384616603298 after 132 th iteration
# mean square error:  0.001587755532077877 after 133 th iteration
# mean square error:  0.0015876765417694506 after 134 th iteration
# mean square error:  0.001587601304061499 after 135 th iteration
# mean square error:  0.00158752964108445 after 136 th iteration
# mean square error:  0.001587461383361458 after 137 th iteration
# mean square error:  0.0015873963694159937 after 138 th iteration
# mean square error:  0.001587334445397452 after 139 th iteration
# mean square error:  0.0015872754647239828 after 140 th iteration
# mean square error:  0.0015872192877416683 after 141 th iteration
# mean square error:  0.0015871657813996249 after 142 th iteration
# mean square error:  0.001587114818939862 after 143 th iteration
# mean square error:  0.0015870662796017105 after 144 th iteration
# mean square error:  0.0015870200483398874 after 145 th iteration
# mean square error:  0.0015869760155555288 after 146 th iteration
# mean square error:  0.0015869340768399065 after 147 th iteration
# mean square error:  0.0015868941327299153 after 148 th iteration
# mean square error:  0.0015868560884750866 after 149 th iteration
# mean square error:  0.0015868198538153244 after 150 th iteration
# mean square error:  0.0015867853427691235 after 151 th iteration
# mean square error:  0.0015867524734316776 after 152 th iteration
# mean square error:  0.0015867211677823138 after 153 th iteration
# mean square error:  0.0015866913515011382 after 154 th iteration
# mean square error:  0.00158666295379411 after 155 th iteration
# mean square error:  0.0015866359072263412 after 156 th iteration
# mean square error:  0.0015866101475633407 after 157 th iteration
# mean square error:  0.001586585613619545 after 158 th iteration
# mean square error:  0.0015865622471140921 after 159 th iteration
# mean square error:  0.0015865399925333247 after 160 th iteration
# mean square error:  0.0015865187969997577 after 161 th iteration
# mean square error:  0.0015864986101472253 after 162 th iteration
# mean square error:  0.001586479384001974 after 163 th iteration
# mean square error:  0.001586461072869198 after 164 th iteration
# mean square error:  0.0015864436332251042 after 165 th iteration
# mean square error:  0.0015864270236139913 after 166 th iteration
# mean square error:  0.0015864112045501561 after 167 th iteration
# mean square error:  0.0015863961384244422 after 168 th iteration
# mean square error:  0.0015863817894152719 after 169 th iteration
# mean square error:  0.0015863681234038578 after 170 th iteration
# mean square error:  0.0015863551078933098 after 171 th iteration
# mean square error:  0.0015863427119317435 after 172 th iteration
# mean square error:  0.0015863309060388732 after 173 th iteration
# mean square error:  0.0015863196621362652 after 174 th iteration
# mean square error:  0.0015863089534805717 after 175 th iteration
# mean square error:  0.0015862987546003573 after 176 th iteration
# mean square error:  0.0015862890412354908 after 177 th iteration
# mean square error:  0.001586279790279774 after 178 th iteration
# mean square error:  0.0015862709797259766 after 179 th iteration
# mean square error:  0.001586262588613736 after 180 th iteration
# mean square error:  0.0015862545969797406 after 181 th iteration
# mean square error:  0.0015862469858103961 after 182 th iteration
# mean square error:  0.0015862397369966277 after 183 th iteration
# mean square error:  0.001586232833290961 after 184 th iteration
# mean square error:  0.0015862262582665156 after 185 th iteration
# mean square error:  0.0015862199962780048 after 186 th iteration
# mean square error:  0.0015862140324245696 after 187 th iteration
# mean square error:  0.001586208352514408 after 188 th iteration
# mean square error:  0.0015862029430310392 after 189 th iteration
# mean square error:  0.0015861977911011936 after 190 th iteration
# mean square error:  0.0015861928844642227 after 191 th iteration
# mean square error:  0.0015861882114429622 after 192 th iteration
# mean square error:  0.001586183760915994 after 193 th iteration
# mean square error:  0.0015861795222911759 after 194 th iteration
# mean square error:  0.0015861754854805197 after 195 th iteration
# mean square error:  0.0015861716408761487 after 196 th iteration
# mean square error:  0.0015861679793275228 after 197 th iteration
# mean square error:  0.001586164492119619 after 198 th iteration
# mean square error:  0.0015861611709522222 after 199 th iteration
# mean square error:  0.0015861580079202292 after 200 th iteration
# mean square error:  0.001586154995494831 after 201 th iteration
# mean square error:  0.001586152126505564 after 202 th iteration
# mean square error:  0.0015861493941233395 after 203 th iteration
# mean square error:  0.001586146791844118 after 204 th iteration
# mean square error:  0.0015861443134734738 after 205 th iteration
# mean square error:  0.0015861419531119024 after 206 th iteration
# mean square error:  0.0015861397051407128 after 207 th iteration
# mean square error:  0.0015861375642087121 after 208 th iteration
# mean square error:  0.0015861355252194446 after 209 th iteration
# mean square error:  0.0015861335833190918 after 210 th iteration
# mean square error:  0.0015861317338849194 after 211 th iteration
# mean square error:  0.001586129972514264 after 212 th iteration
# mean square error:  0.0015861282950140512 after 213 th iteration
# mean square error:  0.0015861266973908749 after 214 th iteration
# mean square error:  0.0015861251758414335 after 215 th iteration
# mean square error:  0.0015861237267434758 after 216 th iteration
# mean square error:  0.0015861223466472553 after 217 th iteration
# mean square error:  0.0015861210322672457 after 218 th iteration
# mean square error:  0.001586119780474339 after 219 th iteration
# mean square error:  0.0015861185882884345 after 220 th iteration
# mean square error:  0.0015861174528713031 after 221 th iteration
# mean square error:  0.0015861163715198527 after 222 th iteration
# mean square error:  0.0015861153416596846 after 223 th iteration
# mean square error:  0.0015861143608389945 after 224 th iteration
# mean square error:  0.0015861134267227204 after 225 th iteration
# mean square error:  0.0015861125370869452 after 226 th iteration
# mean square error:  0.0015861116898136728 after 227 th iteration
# mean square error:  0.0015861108828857443 after 228 th iteration
# mean square error:  0.0015861101143820422 after 229 th iteration
# mean square error:  0.001586109382472938 after 230 th iteration
# mean square error:  0.0015861086854158893 after 231 th iteration
# mean square error:  0.0015861080215513706 after 232 th iteration
# mean square error:  0.0015861073892988195 after 233 th iteration
# mean square error:  0.0015861067871529777 after 234 th iteration
# mean square error:  0.0015861062136802403 after 235 th iteration
# mean square error:  0.0015861056675152713 after 236 th iteration
# mean square error:  0.0015861051473577358 after 237 th iteration
# mean square error:  0.001586104651969231 after 238 th iteration
# mean square error:  0.0015861041801703071 after 239 th iteration
# mean square error:  0.0015861037308376926 after 240 th iteration
# mean square error:  0.0015861033029015905 after 241 th iteration
# mean square error:  0.0015861028953431421 after 242 th iteration
# mean square error:  0.0015861025071920052 after 243 th iteration
# mean square error:  0.0015861021375240519 after 244 th iteration
# mean square error:  0.001586101785459127 after 245 th iteration
# mean square error:  0.0015861014501590308 after 246 th iteration
# mean square error:  0.0015861011308254543 after 247 th iteration
# mean square error:  0.001586100826698077 after 248 th iteration
# mean square error:  0.001586100537052857 after 249 th iteration
# mean square error:  0.0015861002612001427 after 250 th iteration
# mean square error:  0.0015860999984831524 after 251 th iteration
# mean square error:  0.001586099748276405 after 252 th iteration
# mean square error:  0.0015860995099841746 after 253 th iteration
# mean square error:  0.0015860992830391285 after 254 th iteration
# mean square error:  0.0015860990669008914 after 255 th iteration
# mean square error:  0.0015860988610548992 after 256 th iteration
# mean square error:  0.0015860986650110406 after 257 th iteration
# mean square error:  0.0015860984783025434 after 258 th iteration
# mean square error:  0.001586098300484892 after 259 th iteration
# mean square error:  0.0015860981311346986 after 260 th iteration
# mean square error:  0.001586097969848746 after 261 th iteration
# mean square error:  0.0015860978162430528 after 262 th iteration
# mean square error:  0.0015860976699518853 after 263 th iteration
# mean square error:  0.00158609753062693 after 264 th iteration
# mean square error:  0.001586097397936459 after 265 th iteration
# mean square error:  0.0015860972715645827 after 266 th iteration
# mean square error:  0.0015860971512103778 after 267 th iteration
# mean square error:  0.0015860970365872992 after 268 th iteration
# mean square error:  0.0015860969274224504 after 269 th iteration
# mean square error:  0.001586096823455907 after 270 th iteration
# mean square error:  0.001586096724440144 after 271 th iteration
# mean square error:  0.001586096630139391 after 272 th iteration
# mean square error:  0.0015860965403291345 after 273 th iteration
# mean square error:  0.0015860964547955688 after 274 th iteration
# mean square error:  0.001586096373335014 after 275 th iteration
# mean square error:  0.0015860962957535247 after 276 th iteration
# mean square error:  0.001586096221866359 after 277 th iteration
# mean square error:  0.0015860961514976438 after 278 th iteration
# mean square error:  0.0015860960844797979 after 279 th iteration
# mean square error:  0.001586096020653304 after 280 th iteration
# mean square error:  0.0015860959598661334 after 281 th iteration
# mean square error:  0.0015860959019735861 after 282 th iteration
# mean square error:  0.0015860958468378273 after 283 th iteration
# mean square error:  0.0015860957943275842 after 284 th iteration
# mean square error:  0.0015860957443178127 after 285 th iteration
# mean square error:  0.001586095696689467 after 286 th iteration
# mean square error:  0.0015860956513291259 after 287 th iteration
# mean square error:  0.0015860956081287963 after 288 th iteration
# mean square error:  0.0015860955669856308 after 289 th iteration
# mean square error:  0.0015860955278016568 after 290 th iteration
# mean square error:  0.0015860954904835848 after 291 th iteration
# mean square error:  0.0015860954549425555 after 292 th iteration
# mean square error:  0.001586095421093957 after 293 th iteration
# mean square error:  0.001586095388857194 after 294 th iteration
# mean square error:  0.0015860953581555192 after 295 th iteration
# mean square error:  0.0015860953289158295 after 296 th iteration
# mean square error:  0.0015860953010685013 after 297 th iteration
# mean square error:  0.0015860952745472413 after 298 th iteration
# mean square error:  0.0015860952492888851 after 299 th iteration
# 0.006804636870845042

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
plt.plot(range(0,300 ), MSE_points)
plt.xlabel('MSE')
plt.show()
# sns.lineplot(MSE_points)

# %%
pred_df = pd.DataFrame(
    {
        'Actual Value' : Y_test, 
     'Predicted Values' : Y_pred,
    }
)
pred_df.head(10)
# Out:
#    Actual Value  Predicted Values
# 0          37.6         36.092436
# 1          27.9         29.111756
# 2          22.6         26.841347
# 3          13.8          5.619156
# 4          35.2         33.754890
# 5          10.4          6.437483
# 6          23.9         27.149082
# 7          29.0         29.445034
# 8          22.8         26.745459
# 9          23.2         20.599858

# %%
plt.scatter(Y_test, Y_pred)
plt.xlabel("Prices: $Y_i$")
plt.ylabel("Predicted prices: $\hat{Y}_i$")
plt.title("Prices vs Predicted prices: $Y_i$ vs $\hat{Y}_i$")
plt.show()

# %%
plt.scatter(Y_test, y_pred_from_sklearn)
plt.xlabel("Prices: $Y_i$")
plt.ylabel("Predicted prices: $\hat{Y}_i$")
plt.title("Prices vs Predicted prices: $Y_i$ vs $\hat{Y}_i$")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

MSE_custom_LR_Model = mean_squared_error(Y_test, Y_pred)
MSE_sklearn_LR_Model = mean_squared_error(Y_test, y_pred_from_sklearn)

print(MSE_custom_LR_Model)
print(MSE_sklearn_LR_Model)
# Out:
# 30.933923014211647
# 28.530458765974757

# %%
from prettytable import PrettyTable

x = PrettyTable(['Models', 'MSE'])

x.add_row(['Linear Regression (SKLEARN)', MSE_sklearn_LR_Model])
x.add_row(['Linear Regression (From Scratch)', MSE_custom_LR_Model])
print(x)
# Out:
# +----------------------------------+--------------------+
# |              Models              |        MSE         |
# +----------------------------------+--------------------+
# |   Linear Regression (SKLEARN)    | 28.530458765974757 |
# | Linear Regression (From Scratch) | 30.933923014211647 |
# +----------------------------------+--------------------+
