# %%
! pip3 install onnx
# Out:
# Collecting onnx
#   Downloading https://files.pythonhosted.org/packages/f7/c9/1ed7a28d784aa867952c7aa5762c8cfa3596dc0f9f7a190725331bb6d3a0/onnx-1.6.0-cp35-cp35m-manylinux1_x86_64.whl (4.8MB)
#      |████████████████████████████████| 4.8MB 51kB/s  eta 0:00:01
# Requirement already satisfied: protobuf in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from onnx) (3.4.1)
# Requirement already satisfied: numpy in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from onnx) (1.17.3)
# Collecting typing-extensions>=3.6.2.1
#   Downloading https://files.pythonhosted.org/packages/03/92/705fe8aca27678e01bbdd7738173b8e7df0088a2202c80352f664630d638/typing_extensions-3.7.4.1-py3-none-any.whl
# Requirement already satisfied: six in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from onnx) (1.11.0)
# Requirement already satisfied: setuptools in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from protobuf->onnx) (41.6.0)
# Installing collected packages: typing-extensions, onnx
# Successfully installed onnx-1.6.0 typing-extensions-3.7.4.1
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
! pip3 install onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading https://files.pythonhosted.org/packages/79/fc/4649ab7e31fc04fbd6dffff2743c0c3a530f05be25a823fb3b67bfcc3295/onnxruntime-1.2.0-cp35-cp35m-manylinux1_x86_64.whl (3.7MB)
#      |████████████████████████████████| 3.7MB 2.0MB/s eta 0:00:01
# Collecting numpy>=1.18.0
#   Downloading https://files.pythonhosted.org/packages/ff/18/c0b937e2f84095ae230196899e56d1d7d76c8e8424fb235ed7e5bb6d68af/numpy-1.18.2-cp35-cp35m-manylinux1_x86_64.whl (20.0MB)
#      |████████████████████████████████| 20.0MB 14kB/s  eta 0:00:01    |█████▉                          | 3.6MB 6.0MB/s eta 0:00:03
# Requirement already satisfied: onnx>=1.2.3 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from onnxruntime) (1.6.0)
# Requirement already satisfied: protobuf in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from onnx>=1.2.3->onnxruntime) (3.4.1)
# Requirement already satisfied: six in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from onnx>=1.2.3->onnxruntime) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from onnx>=1.2.3->onnxruntime) (3.7.4.1)
# Requirement already satisfied: setuptools in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from protobuf->onnx>=1.2.3->onnxruntime) (41.6.0)
# Installing collected packages: numpy, onnxruntime
#   Found existing installation: numpy 1.17.3
#     Uninstalling numpy-1.17.3:
#       Successfully uninstalled numpy-1.17.3
# Successfully installed numpy-1.18.2 onnxruntime-1.2.0
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
! pip3 install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading https://files.pythonhosted.org/packages/6d/71/e2d3a9f7183e8909a35b085a5b5236131920dd6cbdd3cecfde80f905f674/opencv_contrib_python-4.2.0.32-cp35-cp35m-manylinux1_x86_64.whl (34.2MB)
#      |████████████████████████████████| 34.2MB 108kB/s eta 0:00:011   |▉                               | 942kB 1.9MB/s eta 0:00:18     |████▏                           | 4.5MB 1.9MB/s eta 0:00:16     |████▋                           | 4.9MB 1.9MB/s eta 0:00:16             | 8.3MB 1.9MB/s eta 0:00:14
# Requirement already satisfied: numpy>=1.11.1 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from opencv-contrib-python) (1.18.2)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.2.0.32
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import os
import sys
import onnxruntime
import onnx
import numpy as np
from PIL import Image, ImageDraw
from object_detection import ObjectDetection
import tempfile

import cv2
import matplotlib.pyplot as plt
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
ModelFile ='model.onnx'
ImageFile= 'images.jpeg'

# %%
with open('labels.txt', 'r') as f:
        labels = [l.strip() for l in f.readlines()]

# %%
print(labels)
# Out:
# ['mask']

# %%
class ONNXRuntimeObjectDetection(ObjectDetection):
    """Object Detection class for ONNX Runtime"""
    def __init__(self, model_filename, labels):
        super(ONNXRuntimeObjectDetection, self).__init__(labels)
        model = onnx.load(model_filename)
        with tempfile.TemporaryDirectory() as dirpath:
            temp = os.path.join(dirpath, os.path.basename(ModelFile))
            model.graph.input[0].type.tensor_type.shape.dim[-1].dim_param = 'dim1'
            model.graph.input[0].type.tensor_type.shape.dim[-2].dim_param = 'dim2'
            onnx.save(model, temp)
            self.session = onnxruntime.InferenceSession(temp)
        self.input_name = self.session.get_inputs()[0].name
        self.is_fp16 = self.session.get_inputs()[0].type == 'tensor(float16)'
        
    def predict(self, preprocessed_image):
        inputs = np.array(preprocessed_image, dtype=np.float32)[np.newaxis,:,:,(2,1,0)] # RGB -> BGR
        inputs = np.ascontiguousarray(np.rollaxis(inputs, 3, 1))

        if self.is_fp16:
            inputs = inputs.astype(np.float16)

        outputs = self.session.run(None, {self.input_name: inputs})
        return np.squeeze(outputs).transpose((1,2,0)).astype(np.float32)

# %%
imcv = cv2.imread(ImageFile)
showImage = plt.imshow(imcv)

# %%
od_model = ONNXRuntimeObjectDetection(ModelFile, labels)
image = Image.open(ImageFile)
predictions = od_model.predict_image(image)

# %%
print(predictions)
# Out:
# [{'tagId': 0, 'probability': 0.96042043, 'boundingBox': {'width': 0.18224141, 'top': 0.21173028, 'left': 0.65662966, 'height': 0.24757054}, 'tagName': 'mask'}, {'tagId': 0, 'probability': 0.68741411, 'boundingBox': {'width': 0.21972081, 'top': 0.36580602, 'left': 0.20358689, 'height': 0.28492898}, 'tagName': 'mask'}, {'tagId': 0, 'probability': 0.11113014, 'boundingBox': {'width': 0.08968096, 'top': 0.8766922, 'left': -0.01177648, 'height': 0.11785082}, 'tagName': 'mask'}]

# %%
height, width, channels = imcv.shape
print(height)
print(width)
# Out:
# 183
# 275

# %%
length = len(predictions) 
for i in range(length): 
    left1 = predictions[i]['boundingBox']['left']
    top1 = predictions[i]['boundingBox']['top']
    width1 = predictions[i]['boundingBox']['width']
    height1 = predictions[i]['boundingBox']['height']
    pre = predictions[i]['probability']
    if(pre > 0.5 ):
        left= (int)(left1 * width)
        top = (int)(top1 * height)
        w = (int)(width1 * width + left)
        h = (int)(height1 * height + top)
        cv2.rectangle(imcv,(left,top ),(w,h),(100,0,0),3 )

# %%
imgplot = plt.imshow(imcv)
