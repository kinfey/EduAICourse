# %%
! pip3 install onnx
# Out:
# Requirement already satisfied: onnx in c:\users\kinfeylo\appdata\local\programs\python\python38\lib\site-packages (1.10.2)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\kinfeylo\appdata\local\programs\python\python38\lib\site-packages (from onnx) (1.19.5)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in c:\users\kinfeylo\appdata\local\programs\python\python38\lib\site-packages (from onnx) (3.7.4.3)
# Requirement already satisfied: six in c:\users\kinfeylo\appdata\local\programs\python\python38\lib\site-packages (from onnx) (1.15.0)
# Requirement already satisfied: protobuf in c:\users\kinfeylo\appdata\local\programs\python\python38\lib\site-packages (from onnx) (3.18.1)

# %%
! pip3 install onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading onnxruntime-1.9.0-cp38-cp38-win_amd64.whl (5.1 MB)
# Requirement already satisfied: protobuf in c:\users\kinfeylo\appdata\local\programs\python\python38\lib\site-packages (from onnxruntime) (3.18.1)
# Requirement already satisfied: flatbuffers in c:\users\kinfeylo\appdata\local\programs\python\python38\lib\site-packages (from onnxruntime) (1.12)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\kinfeylo\appdata\local\programs\python\python38\lib\site-packages (from onnxruntime) (1.19.5)
# Installing collected packages: onnxruntime
# Successfully installed onnxruntime-1.9.0

# %%
! pip3 install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.5.4.58-cp38-cp38-win_amd64.whl (42.0 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\kinfeylo\appdata\local\programs\python\python38\lib\site-packages (from opencv-contrib-python) (1.19.5)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.5.4.58

# %%
import os
import sys
import onnxruntime
import onnx
import numpy as np
from PIL import Image, ImageDraw
from object_detection import ObjectDetection
import tempfile

import cv2
import matplotlib.pyplot as plt

# %%
ModelFile ='model.onnx'
ImageFile= 'images.jpeg'

# %%
with open('labels.txt', 'r') as f:
        labels = [l.strip() for l in f.readlines()]

# %%
print(labels)
# Out:
# ['mask']

# %%
class ONNXRuntimeObjectDetection(ObjectDetection):
    """Object Detection class for ONNX Runtime"""
    def __init__(self, model_filename, labels):
        super(ONNXRuntimeObjectDetection, self).__init__(labels)
        model = onnx.load(model_filename)
        with tempfile.TemporaryDirectory() as dirpath:
            temp = os.path.join(dirpath, os.path.basename(ModelFile))
            model.graph.input[0].type.tensor_type.shape.dim[-1].dim_param = 'dim1'
            model.graph.input[0].type.tensor_type.shape.dim[-2].dim_param = 'dim2'
            onnx.save(model, temp)
            self.session = onnxruntime.InferenceSession(temp)
        self.input_name = self.session.get_inputs()[0].name
        self.is_fp16 = self.session.get_inputs()[0].type == 'tensor(float16)'
        
    def predict(self, preprocessed_image):
        inputs = np.array(preprocessed_image, dtype=np.float32)[np.newaxis,:,:,(2,1,0)] # RGB -> BGR
        inputs = np.ascontiguousarray(np.rollaxis(inputs, 3, 1))

        if self.is_fp16:
            inputs = inputs.astype(np.float16)

        outputs = self.session.run(None, {self.input_name: inputs})
        return np.squeeze(outputs).transpose((1,2,0)).astype(np.float32)

# %%
imcv = cv2.imread(ImageFile)
showImage = plt.imshow(imcv)

# %%
od_model = ONNXRuntimeObjectDetection(ModelFile, labels)
image = Image.open(ImageFile)
predictions = od_model.predict_image(image)

# %%
print(predictions)
# Out:
# [{'probability': 0.98582155, 'tagId': 0, 'tagName': 'mask', 'boundingBox': {'left': 0.65207027, 'top': 0.20951238, 'width': 0.19225674, 'height': 0.24413884}}, {'probability': 0.74439752, 'tagId': 0, 'tagName': 'mask', 'boundingBox': {'left': 0.20645266, 'top': 0.38309157, 'width': 0.22177884, 'height': 0.26870849}}]

# %%
height, width, channels = imcv.shape
print(height)
print(width)
# Out:
# 183
# 275

# %%
length = len(predictions) 
for i in range(length): 
    left1 = predictions[i]['boundingBox']['left']
    top1 = predictions[i]['boundingBox']['top']
    width1 = predictions[i]['boundingBox']['width']
    height1 = predictions[i]['boundingBox']['height']
    pre = predictions[i]['probability']
    if(pre > 0.5 ):
        left= (int)(left1 * width)
        top = (int)(top1 * height)
        w = (int)(width1 * width + left)
        h = (int)(height1 * height + top)
        cv2.rectangle(imcv,(left,top ),(w,h),(100,0,0),3 )

# %%
imgplot = plt.imshow(imcv)
